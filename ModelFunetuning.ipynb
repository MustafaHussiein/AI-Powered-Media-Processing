# %% [markdown]
# <a href="https://colab.research.google.com/github/MustafaHussiein/AI-Powered-Media-Processing/blob/main/ModelFunetuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade transformers
# !pip install rouge-score
from transformers import AutoTokenizer, TrainingArguments, Trainer, BertForQuestionAnswering, pipeline
from sklearn.metrics import precision_score, recall_score, f1_score
from difflib import SequenceMatcher
import numpy as np
import csv
import time
import torch
from nltk.translate.bleu_score import sentence_bleu
import pandas as pd
import os
from datasets import load_dataset, DatasetDict
from rouge_score import rouge_scorer
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.54.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.34.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.7.14)
# Requirement already satisfied: rouge-score in /usr/local/lib/python3.11/dist-packages (0.1.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rouge-score) (2.0.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (4.67.1)

# %%
torch.cuda.empty_cache()
models = ["bert-base-multilingual-cased","bert-large-uncased-whole-word-masking-finetuned-squad", "roberta-base", "bert-base-uncased", "aubmindlab/bert-base-arabertv02"]
tokenizers = [AutoTokenizer.from_pretrained(model_name, use_fast = True) for model_name in models]
models_org = [BertForQuestionAnswering.from_pretrained(model_name) for model_name in models]
# Initialize the QA pipeline
qa_pipelines_org = [pipeline("question-answering", model=model, tokenizer=tokenizer) for model,tokenizer in zip(models_org, tokenizers)]
output_filename = 'results.xlsx'
sheet_name = 'Sheet1'
file_paths = ['arabic_samples.xlsx', 'DAWQAS_Masun_Nabhan_Homsi.xlsx']
metrics_headers = ['Dataset', 'Model name', 'Question', 'Type', 'Actual answer',
                   'Answer','Blue' , 'Rouge1_Precision', 'Rouge1_Recall',
                   'Rouge1_Fmeasure', 'Rouge2_Precision', 'Rouge2_Recall',
                   'Rouge2_Fmeasure', 'RougeL_Precision', 'RougeL_Recall',
                   'RougeL_Fmeasure', 'EM', 'SM', 'Inference_time', 'Tuning']
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/443 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/381 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/384 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-large-uncased-whole-word-masking-finetuned-squad were not used when initializing BertForQuestionAnswering: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# You are using a model of type roberta to instantiate a model of type bert. This is not supported for all configurations of models and can yield errors.
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at roberta-base and are newly initialized: ['bert.embeddings.LayerNorm.bias', 'bert.embeddings.LayerNorm.weight', 'bert.embeddings.position_embeddings.weight', 'bert.embeddings.token_type_embeddings.weight', 'bert.embeddings.word_embeddings.weight', 'bert.encoder.layer.0.attention.output.LayerNorm.bias', 'bert.encoder.layer.0.attention.output.LayerNorm.weight', 'bert.encoder.layer.0.attention.output.dense.bias', 'bert.encoder.layer.0.attention.output.dense.weight', 'bert.encoder.layer.0.attention.self.key.bias', 'bert.encoder.layer.0.attention.self.key.weight', 'bert.encoder.layer.0.attention.self.query.bias', 'bert.encoder.layer.0.attention.self.query.weight', 'bert.encoder.layer.0.attention.self.value.bias', 'bert.encoder.layer.0.attention.self.value.weight', 'bert.encoder.layer.0.intermediate.dense.bias', 'bert.encoder.layer.0.intermediate.dense.weight', 'bert.encoder.layer.0.output.LayerNorm.bias', 'bert.encoder.layer.0.output.LayerNorm.weight', 'bert.encoder.layer.0.output.dense.bias', 'bert.encoder.layer.0.output.dense.weight', 'bert.encoder.layer.1.attention.output.LayerNorm.bias', 'bert.encoder.layer.1.attention.output.LayerNorm.weight', 'bert.encoder.layer.1.attention.output.dense.bias', 'bert.encoder.layer.1.attention.output.dense.weight', 'bert.encoder.layer.1.attention.self.key.bias', 'bert.encoder.layer.1.attention.self.key.weight', 'bert.encoder.layer.1.attention.self.query.bias', 'bert.encoder.layer.1.attention.self.query.weight', 'bert.encoder.layer.1.attention.self.value.bias', 'bert.encoder.layer.1.attention.self.value.weight', 'bert.encoder.layer.1.intermediate.dense.bias', 'bert.encoder.layer.1.intermediate.dense.weight', 'bert.encoder.layer.1.output.LayerNorm.bias', 'bert.encoder.layer.1.output.LayerNorm.weight', 'bert.encoder.layer.1.output.dense.bias', 'bert.encoder.layer.1.output.dense.weight', 'bert.encoder.layer.10.attention.output.LayerNorm.bias', 'bert.encoder.layer.10.attention.output.LayerNorm.weight', 'bert.encoder.layer.10.attention.output.dense.bias', 'bert.encoder.layer.10.attention.output.dense.weight', 'bert.encoder.layer.10.attention.self.key.bias', 'bert.encoder.layer.10.attention.self.key.weight', 'bert.encoder.layer.10.attention.self.query.bias', 'bert.encoder.layer.10.attention.self.query.weight', 'bert.encoder.layer.10.attention.self.value.bias', 'bert.encoder.layer.10.attention.self.value.weight', 'bert.encoder.layer.10.intermediate.dense.bias', 'bert.encoder.layer.10.intermediate.dense.weight', 'bert.encoder.layer.10.output.LayerNorm.bias', 'bert.encoder.layer.10.output.LayerNorm.weight', 'bert.encoder.layer.10.output.dense.bias', 'bert.encoder.layer.10.output.dense.weight', 'bert.encoder.layer.11.attention.output.LayerNorm.bias', 'bert.encoder.layer.11.attention.output.LayerNorm.weight', 'bert.encoder.layer.11.attention.output.dense.bias', 'bert.encoder.layer.11.attention.output.dense.weight', 'bert.encoder.layer.11.attention.self.key.bias', 'bert.encoder.layer.11.attention.self.key.weight', 'bert.encoder.layer.11.attention.self.query.bias', 'bert.encoder.layer.11.attention.self.query.weight', 'bert.encoder.layer.11.attention.self.value.bias', 'bert.encoder.layer.11.attention.self.value.weight', 'bert.encoder.layer.11.intermediate.dense.bias', 'bert.encoder.layer.11.intermediate.dense.weight', 'bert.encoder.layer.11.output.LayerNorm.bias', 'bert.encoder.layer.11.output.LayerNorm.weight', 'bert.encoder.layer.11.output.dense.bias', 'bert.encoder.layer.11.output.dense.weight', 'bert.encoder.layer.2.attention.output.LayerNorm.bias', 'bert.encoder.layer.2.attention.output.LayerNorm.weight', 'bert.encoder.layer.2.attention.output.dense.bias', 'bert.encoder.layer.2.attention.output.dense.weight', 'bert.encoder.layer.2.attention.self.key.bias', 'bert.encoder.layer.2.attention.self.key.weight', 'bert.encoder.layer.2.attention.self.query.bias', 'bert.encoder.layer.2.attention.self.query.weight', 'bert.enco ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# model.safetensors:   0%|          | 0.00/543M [00:00<?, ?B/s]
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at aubmindlab/bert-base-arabertv02 and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Device set to use cuda:0
# Device set to use cuda:0
# Device set to use cuda:0
# Device set to use cuda:0
# Device set to use cuda:0

# %%
#------elimination of _x000D
def preprocess_text(text):
    # Replace any non-printable or special characters
    text = text.replace('_x000D_', ' ').strip()
    return text
#-----------------------------------------------
#----------------preprocessing data
def preprocess_function(examples, tokenizer):
    questions = [q.strip() for q in examples["question"]]
    contexts = [c.strip() for c in examples["context"]]
    answers = examples["answers"]

    inputs = tokenizer(
        questions,
        contexts,
        truncation=True,
        padding="max_length",
        max_length=512,
        return_offsets_mapping=True,
        return_tensors="pt"
    )

    offset_mapping = inputs.pop("offset_mapping")
    start_positions_tokenized = []
    end_positions_tokenized = []

    for i, offsets in enumerate(offset_mapping):
        context = contexts[i]
        answer = answers[i]

        # Extract the text of the answer
        if isinstance(answer, dict):
            answer_text = answer["text"]
        else:
            answer_text = answer

        # Find the start character index of the answer text in the context
        start_char = context.find(answer_text)

        # If the answer is not found, you can handle it by defaulting to 0 or skipping
        if start_char == -1:
            # Here, we skip the entry
            print(f"Answer not found in context for entry {i}. Skipping.")
            start_positions_tokenized.append(0)
            end_positions_tokenized.append(0)
            continue

        end_char = start_char + len(answer_text)

        # Find the start and end token indices based on offsets
        start_token = None
        end_token = None

        for idx, (start, end) in enumerate(offsets):
            if start <= start_char < end:
                start_token = idx
            if start < end_char <= end:
                end_token = idx
                break

        # Default to the first token if not found (for robustness)
        if start_token is None:
            start_token = 0
        if end_token is None:
            end_token = 0

        start_positions_tokenized.append(start_token)
        end_positions_tokenized.append(end_token)

    inputs["start_positions"] = start_positions_tokenized
    inputs["end_positions"] = end_positions_tokenized

    return inputs
#----------------------------------------------------------------------
#------------------getting answer
def get_answer_bert(paragraph, question, model, s_p, e_p, tokenizer):
    model.to("cuda")
    if paragraph and isinstance(paragraph, str) and paragraph.strip():
        # Combine question and paragraph into a single input string
        input_text = f"Context: {paragraph}\nQuestion: {question}\nAnswer:"
    else:
        # If no paragraph is provided, only use the question
        input_text = f"Question: {question}\nAnswer:"
    # Tokenize the input
    inputs = tokenizer(
        input_text,
        return_tensors='pt',
        padding='max_length',  # Adjust padding based on max length
        truncation=True,
        max_length=512
    ).to("cuda")
    input_ids = inputs["input_ids"]
    # Perform text generation (inference) with max_new_tokens for generated output
    with torch.no_grad():
        outputs = model(**inputs)

    # Extract the logits for start and end positions
    start_logits = outputs.start_logits
    end_logits = outputs.end_logits

    # Get the most likely start and end indices
    start_index = torch.argmax(outputs.start_logits)
    end_index = torch.argmax(outputs.end_logits)

    # Convert indices to tokens and decode
    answer_ids = input_ids[0][start_index:end_index + 1]
    answer = tokenizer.decode(answer_ids)

    # Return the answer, predicted spans, and reference spans
    pred_spans = [(start_index.item(), end_index.item())]
    ref_spans = [(s_p, e_p)]

    return answer, pred_spans, ref_spans
#----------------------------------------
#--------------------------------------evaluation of answers
def span_match(predictions, references, pred_spans, ref_spans):
    """
    Calculate the Span Matching (SM) score.

    Args:
        predictions (list of str): The list of predicted answers.
        references (list of str): The list of actual answers.
        pred_spans (list of tuples): The list of predicted spans (start, end).
        ref_spans (list of tuples): The list of reference spans (start, end).

    Returns:
        float: The Span Matching score as a percentage.
    """
    assert len(predictions) == len(references) == len(pred_spans) == len(ref_spans), "All input lists must be of the same length"

    def spans_match(pred_span, ref_span):
        return pred_span == ref_span

    span_matches = [1 if spans_match(ps, rs) else 0 for ps, rs in zip(pred_spans, ref_spans)]
    sm_score = sum(span_matches) / len(references) * 100
    return sm_score


def evaluate_answers(predicted, actual, pred_spans, ref_spans):
    references = [actual.split(' ')]
    predictions = [predicted.split(' ')]
    blue = sentence_bleu(references, predicted.split(' '))
    r_scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    # Compute the ROUGE scores
    rouge = r_scorer.score(actual, predicted)
    rouge1 = rouge['rouge1']
    rouge2 = rouge['rouge2']
    rougeL = rouge['rougeL']
    exact_matches = [1 if p == r else 0 for p, r in zip(predictions, references)]
    em_score = sum(exact_matches) / len(references) * 100
    sm_score = span_match(predictions, references, pred_spans, ref_spans)
    return blue, rouge1.precision, rouge1.recall, rouge1.fmeasure, rouge2.precision, rouge2.recall, rouge2.fmeasure, rougeL.precision, rougeL.recall, rougeL.fmeasure, em_score,sm_score
#-----------------------------------------------------------------------------
#-------------------------------------------------saving results to csv file
def write_to_csv(filename, field_names, data):
    # Check if the file exists
    file_exists = False
    try:
        with open(filename, 'r', encoding='utf-8-sig') as file:
            file_exists = True
    except FileNotFoundError:
        file_exists = False

    # Open the CSV file in the appropriate mode with UTF-8 encoding
    mode = 'a' if file_exists else 'w'
    with open(filename, mode, newline='', encoding='utf-8-sig') as file:
        writer = csv.writer(file)

        # Write a new line if the file is empty
        if not file_exists:
            writer.writerow(field_names)  # Example column headers

        # Write the data to the file
        writer.writerow(data)
#----------------------------------------------------------
# --------------------------------define the metrics for evaluation
def compute_metrics(pred):
    predictions_tuple, label_ids_tuple = pred

    # Flatten predictions and labels for metric computation
    all_predictions = []
    all_labels = []

    for predictions, label_ids in zip(predictions_tuple, label_ids_tuple):
        predicted_labels = np.argmax(predictions, axis=-1)

        all_predictions.extend(predicted_labels)
        all_labels.extend(label_ids)

    # Calculate metrics
    accuracy = np.mean(np.array(all_predictions) == np.array(all_labels))
    precision = precision_score(all_labels, all_predictions, average='weighted')
    recall = recall_score(all_labels, all_predictions, average='weighted')
    f1 = f1_score(all_labels, all_predictions, average='weighted')

    return {
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1": f1
    }
#---------------------------------------------------------------------------
#---------------------------------define the callback class
from transformers import TrainerCallback
class SaveMetricsCallback(TrainerCallback):
    def __init__(self, filename):
        self.filename = filename
        self.headers_written = False

    def on_evaluate(self, args, state, control, metrics=None, **kwargs):
        if metrics:
            with open(self.filename, 'a', newline='', encoding='utf-8-sig') as csvfile:
                writer = csv.writer(csvfile)
                if not self.headers_written:
                    # Write headers only once
                    writer.writerow(['epoch', 'eval_loss', 'eval_accuracy', 'eval_precision', 'eval_recall', 'eval_f1'])
                    self.headers_written = True
                writer.writerow([state.epoch, metrics.get('eval_loss'), metrics.get('eval_accuracy'), metrics.get('eval_precision'), metrics.get('eval_recall'), metrics.get('eval_f1')])

# Example compute_metrics function (adjust as per your requirements)
def compute_metrics(pred):
    predictions_tuple, label_ids_tuple = pred

    accuracies = []
    for predictions, label_ids in zip(predictions_tuple, label_ids_tuple):
        accuracy = (np.argmax(predictions, axis=-1) == label_ids).astype(float).mean().item()
        accuracies.append(accuracy)

    return {"accuracy": np.mean(accuracies)}  # Mean accuracy across all predictions
#-----------------------------------------------------------------------
#--------------------------------------------testing model
def test(dataset_name, dataset_sample, model_name, model, tokenizer, case):
    for data in dataset_sample:
        paragraph = data["context"]
        question = data["question"]
        start_p = data["start_positions"]

        # Debugging print to understand the structure of answers
        print("Answers field:", data["answers"])

        # Check if 'answers' is a string or a dictionary
        if isinstance(data["answers"], dict):
            actual_answer = data["answers"]["text"]  # Assuming answers is a dictionary with "text" key
        else:
            actual_answer = data["answers"]  # Assuming answers is a string
        end_p = start_p + len(actual_answer)
        # Get answer without paragraph
        st = time.time()
        if question:
            answer_without_paragraph, pred_spans_without, ref_spans_without = get_answer_bert(" ", question, model, 0, 0, tokenizer)
        else:
            answer_without_paragraph, pred_spans_without, ref_spans_without = " ", [(0,0)], [(0,0)]
        time_without = time.time() - st
        # Get answer with paragraph
        st = time.time()
        if question:
            answer_with_paragraph, pred_spans_with, ref_spans_with = get_answer_bert(paragraph, question, model, 0, 0, tokenizer)
        else:
            answer_with_paragraph, pred_spans_with, ref_spans_with = " ", [(0,0)], [(0,0)]
        time_with = time.time() - st
        print(f"Question: {question}")
        print(f"Actual Answer: {actual_answer}")
        print(f"Answer without Paragraph: {answer_without_paragraph}")
        print(f"Answer with Paragraph: {answer_with_paragraph}")
        print("-------")
        # Evaluate answers and prepare data for CSV
        blue_without, precision1_without, recall1_without, fmeasure1_without, precision2_without, recall2_without, fmeasure2_without, precisionL_without, recallL_without, fmeasureL_without, em_without, sm_without = evaluate_answers(answer_without_paragraph, actual_answer, pred_spans_without, ref_spans_without)
        row_without = [dataset_name, model_name, question, 'without paragraph', actual_answer, answer_without_paragraph, blue_without, precision1_without, recall1_without, fmeasure1_without, precision2_without, recall2_without, fmeasure2_without, precisionL_without, recallL_without, fmeasureL_without, em_without, sm_without, time_without, case]

        blue_with, precision1_with, recall1_with, fmeasure1_with, precision2_with, recall2_with, fmeasure2_with, precisionL_with, recallL_with, fmeasureL_with, em_with, sm_with = evaluate_answers(answer_with_paragraph, actual_answer, pred_spans_with, ref_spans_with)
        row_with = [dataset_name, model_name, question, 'with paragraph', actual_answer, answer_with_paragraph, blue_with, precision1_with, recall1_with, fmeasure1_with, precision2_with, recall2_with, fmeasure2_with, precisionL_with, recallL_with, fmeasureL_with, em_with, sm_with, time_with, case]
        # Write to CSV
        write_to_csv('results.csv', metrics_headers, row_without)
        write_to_csv('results.csv', metrics_headers, row_with)
#-----------------------------------------------------------------------------
#--------------------------------------------------training parameters
training_args = TrainingArguments(
    output_dir='./results',
    eval_strategy="epoch", # Changed from EvaluationStrategy
    learning_rate=0.1,
    per_device_train_batch_size=2,
    per_device_eval_batch_size=2,
    num_train_epochs=100,
    weight_decay=0.01,
)
#------------------------------------------------------------------------------

# %%
for file_path in file_paths:
    dataset_name = file_path.split('.')[0]
    preprocessed_dataset = 'qa_dataset_prepared' + '_' + dataset_name + '.csv'
    if os.path.exists(file_path):
        df = pd.read_excel(file_path, sheet_name='Sheet1')  # Replace 'Sheet1' with your sheet name
        # Example to convert the DataFrame to a list of dictionaries
        data = []
        for index, row in df.iterrows():
            start_position =  row["context"].find(row["answers"])
            data.append({
                "context": row["context"],
                "question": row["question"],
                "start_positions": start_position,
                "answers": row["answers"]
            })

        # Convert to pandas DataFrame and then to Dataset
        df_prepared = pd.DataFrame(data)
        df_prepared.to_csv(preprocessed_dataset, index=False, encoding='utf-8-sig')

    # Load the dataset
    dataset = load_dataset('csv', data_files=preprocessed_dataset)
    split_dataset = dataset['train'].train_test_split(test_size=0.2)  # Adjust test_size as needed
    dataset = DatasetDict({
        'train': split_dataset['train'],
        'test': split_dataset['test']
    })
    # Sample data for debugging
    dataset_sample = []
    for i in range(len(dataset["test"])):
        dataset_sample.append({
        "context": dataset["test"]["context"][i],
        "question": dataset["test"]["question"][i],
        "answers": dataset["test"]["answers"][i],
        "start_positions": dataset["test"]["start_positions"][i] })
    for i in range(len(models_org)):
        test(dataset_name, dataset_sample, models[i], models_org[i], tokenizers[i], 'before tuning')
        tokenized_datasets = dataset.map(lambda examples: preprocess_function(examples, tokenizers[i]), batched=True)
        trained_name = './fine_tuned_bert_'+ models[i] + '_' + dataset_name
        if os.path.isdir(trained_name) == False:
            model = models_org[i]
            model.to("cuda")
            tokenizer = tokenizers[i]
            trainer = Trainer(
                model=model,
                args=training_args,
                train_dataset=tokenized_datasets['train'],
                eval_dataset=tokenized_datasets['test'],
                compute_metrics=compute_metrics,

            )

            # Add the metrics saving callback before training starts
            trainer.add_callback(SaveMetricsCallback('training_metrics.csv'))

            # Start training
            trainer.train()

            # Evaluate after training
            trainer.evaluate()

            # Save the fine-tuned model and tokenizer
            model.save_pretrained(trained_name)
            tokenizer.save_pretrained(trained_name)
        model_trained = BertForQuestionAnswering.from_pretrained(trained_name)
        tokenizer_trained = AutoTokenizer.from_pretrained(trained_name, use_fast = True)
        # AutoTokenizer.from_pretrained(trained_name, use_fast = True)
        qa_pipeline_trained = pipeline("question-answering", model=model_trained, tokenizer=tokenizer_trained)
        test(dataset_name, dataset_sample, models[i], model_trained, tokenizer_trained, 'after tuning')
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Answers field: عملها لسنوات عديدة في الساحة الموسيقية الدنماركية
# Question: ما سبب حصول ان لينيت على جائزة الشرف من الاتحاد الدولي للصناعة الفونوغرافية ؟
# Actual Answer: عملها لسنوات عديدة في الساحة الموسيقية الدنماركية
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: شارك مع منتخب إنجلترا تحت 18 سنة لكرة القدم ومنتخب إنجلترا تحت 19 سنة لكرة القدم.
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Question: كيف كانت مشاركة اللاعب سيمون إيستوود مع منتخب انجلترا؟
# Actual Answer: شارك مع منتخب إنجلترا تحت 18 سنة لكرة القدم ومنتخب إنجلترا تحت 19 سنة لكرة القدم.
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: يوجد بها مسجد يعود بناءه إلى عام 1848 حسب ما يروى
# Question: لماذا تعد الفائدية من أقدم مناطق الجبل  الأخضر؟
# Actual Answer: يوجد بها مسجد يعود بناءه إلى عام 1848 حسب ما يروى
# Answer without Paragraph:
# Answer with Paragraph: يربط بين مدينة المرج ولملودة كما يوجد طريق يربط الفائدية بالطريق الرئيسي البيضاء شحات وهذا طوله حوالي 13 كم كما يوجد في منطقة الفائدية اثار موجودة إلى الآن ( القلعة ) وهي تعود للعهد العثماني ومنطقة الفائدية هي من أقدم مناطق الجبل الأخضر حيث يوجد بها مسجد يعود بناءه إلى عام 1848 حسب ما يروى ، غير ان كثير من الناس لايصلون فيه لوجد قبور كثيرة تحيط يالمسجد وتحيط به كما تعتبر الفائدية مسرحا لعدد كثير من المعارك التي دارت بين الطليان والمجاهدين تتميز الفائدية بارتفاع شاهق مما يجعل المناخ شتاء بارد جدا وفي الصيف معتدل جدا كما يمكنك وانت واقف في أماكن معينة في الفائدية روية مناطق بعيدة مثل مدينة البيضاء وقرنادة ولبرق وغيرها كما تتسم المنطقة برابطة اجتماعية جيدة وتوجد بها جمعية خيرية تقوم بتنفيذ العديد من الاعمال الخيرية. _ x000D _ _ x
# -------
# Answers field: عندما تتعرض النباتات لرعي مكثف لفترات طويلة من الوقت
# Question: كيف  يحدث الافراط في الرعي ؟
# Actual Answer: عندما تتعرض النباتات لرعي مكثف لفترات طويلة من الوقت
# Answer without Paragraph:
# Answer with Paragraph: ##أشخاص أو الفائض في أعداد الحيوانات البرية التي لا يكون هذا موطنها الأصلي. ينتج عنه تقليل الإنتاجية ، والتنوع البيولوجي وهو أحد أسباب التصحر وتعرية التربة. كما يعتبر الرعي أحد أسباب انتشار النباتات في أماكن غير موطنها الأصلي. الرعي الجائر هو أحد الأمثلة القانونية في مقالة " مأساة المشاع " التي نشرت في مجلة العلم في عام 1968. _ x
# -------
# Answers field: ليخدم مناطق الشجاعية، والشعف، وحي الدرج
# Question: ما سبب إنشاء مستشفى الشهيد محمد الدرة للأطفال؟
# Actual Answer: ليخدم مناطق الشجاعية، والشعف، وحي الدرج
# Answer without Paragraph:
# Answer with Paragraph: المستشفى موقف سيارات
# -------
# Answers field: بعد خلع السلطان عبد الحميد الثاني من قبل الاتحادين الاتراك
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Streaming output truncated to the last 5000 lines.
# Actual Answer:  حزمة الأشعة المستخدمة هنا تكون عبارة عن نيترونات بدلاً من الفوتونات.
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: الانكماش الزجاجي
# Question: ما سبب الأبصار الومضي؟
# Actual Answer: الانكماش الزجاجي
# Answer without Paragraph:
# Answer with Paragraph: الزجاجي أو التسييل والذي هو من الأسباب الأكثر شيوعا ل
# -------
# Answers field: ونها الدولة المستضيفة للمسابقة._x000D_
#
# Question: لماذا تجاوزت بولندا تصفيات بطولة اوربا ؟
# Actual Answer: ونها الدولة المستضيفة للمسابقة._x000D_
#
# Answer without Paragraph:
# Answer with Paragraph: ##ست المنتخبات فيما بينها لتحديد هوية المتأهلين إلى بطولة أوروبا تحت 21 سنة لكرة القدم 2017. تأهل 11 منتخب من هذه التصفيات إلى المسابقة النهائية بالإضافة إلى بولندا التي تأهلت تلقائيا دون خوض التصفيات ، كونها الدولة المست
# -------
# Answers field: تأليفه لقصص مشهورة مثل جومانجي في سنة 1981
# Question: ما سبب ذياع صيت آلسبورغ؟
# Actual Answer: تأليفه لقصص مشهورة مثل جومانجي في سنة 1981
# Answer without Paragraph:
# Answer with Paragraph: دكتور
# -------
# Answers field: وبذلك يكون الرأس قادرا بفعل الضغط الهائل (وليس الحرارة) على اختراق الدرع واحداث الفجوة
# Question: كيف يتم اختراق الدرع واحداث فجوة؟
# Actual Answer: وبذلك يكون الرأس قادرا بفعل الضغط الهائل (وليس الحرارة) على اختراق الدرع واحداث الفجوة
# Answer without Paragraph:
# Answer with Paragraph: ولا المسافة الكافيان للتشكل والوصول للسرعة القصوى. ولذلك فإن أغلب الرؤوس المضادة للدبابات تحتوي في مقدمتها على مجس التباعد لقياس المسافة
# -------
# Answers field: بدأ مسيرته الفنية عام 1986 وهو في العشرين من عمره.
# Question: كيف بدا مسيرته؟
# Actual Answer: بدأ مسيرته الفنية عام 1986 وهو في العشرين من عمره.
# Answer without Paragraph: ##wer : [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Answer with Paragraph:
# -------
# Answers field:  نبعت من رالف ويدرو
# Question: كيف اتت فكرة البيتاترون ؟
# Actual Answer:  نبعت من رالف ويدرو
# Answer without Paragraph: ##wer : [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Answer with Paragraph:
# -------
# Answers field: دعم جهود مقدمة من افراد أو منظمات أخرى
# Question: لماذا تتم عمليات التمويل الجماعي عبر الانترنت؟
# Actual Answer: دعم جهود مقدمة من افراد أو منظمات أخرى
# Answer without Paragraph:
# Answer with Paragraph: على الثقة وشبكة العلاقات بين الأفراد الذين يجمعون الأموال والموارد الأخرى سويا, غالباً عبر الإنترنت بهدف دعم جهود مقدمة من افراد أو منظمات أخرى. تتم عملية التمويل الجماعي بهدف دعم العديد من الأهداف, منها على سبيل المثال عمليات الإغاثة في حالات الكوارث, صحافة الشارع, دعم الفنانين الذين يحتاجون للدعم من المعجبين, دعم الحملات الانتخابية, تم
# -------
# Answers field: مُضمَّنة في مجموعة همنغواي القصصية
# Question: كيف تم إعادة نشر القصة؟
# Actual Answer: مُضمَّنة في مجموعة همنغواي القصصية
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: الدرز الجبهي (الناصف)، يساهم في تشكيل كل من الحفرة القحفية الأمامية وقاعدة القحف
# Question: كيف تتكون الحفرة القحفية الأمامية وقاعدة القحف؟
# Actual Answer: الدرز الجبهي (الناصف)، يساهم في تشكيل كل من الحفرة القحفية الأمامية وقاعدة القحف
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field:  زعيم الحزب الديمقراطي الاجتماعي الألمان
# Question: لماذا يعد فيلي براندت من رجال دولة ألمانيا اللذين شغول منصب استشاري وسياسي؟
# Actual Answer:  زعيم الحزب الديمقراطي الاجتماعي الألمان
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: للدلالة على العصور الوسطى في أوروبا وهي الفترة ما بين الأعوام 400 - 1400 تقريبا
# Question: ما سبب استخدام مصطلح العصور المظلمة في علم التاريخ؟
# Actual Answer: للدلالة على العصور الوسطى في أوروبا وهي الفترة ما بين الأعوام 400 - 1400 تقريبا
# Answer without Paragraph:
# Answer with Paragraph: بتوسيع المصطلح ليشمل أيضًا غيا
# -------
# Answers field: من خلال وسائل الإعلام
# Question: كيف زاد التفاعل العالمي؟
# Actual Answer: من خلال وسائل الإعلام
# Answer without Paragraph: ##wer : [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Answer with Paragraph:
# -------
# Answers field: ودخوله منتصرا
# Question: كيف دخل الى لندن ؟
# Actual Answer: ودخوله منتصرا
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: اتصال برقي بين أمريكا وأوروبا، لكان من الممكن جدًا تجنب الحرب
# Question: لماذا سميت حرب 1812 بالحرب الاتصال؟
# Actual Answer: اتصال برقي بين أمريكا وأوروبا، لكان من الممكن جدًا تجنب الحرب
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: أراد الشيخ جاسم بن محمد آل ثاني الأنتقام من أبوظبي
# Question: لماذا حدثت خراب الدوحه الرايع؟
# Actual Answer: أراد الشيخ جاسم بن محمد آل ثاني الأنتقام من أبوظبي
# Answer without Paragraph: Answer : [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Answer with Paragraph: خليفة بن زاي
# -------
# Answers field: حسب عدد السكان
# Question: علل سبب اعتبار سان جيروم في المركز التاسع والسبعون من بين مدن كندا؟
# Actual Answer: حسب عدد السكان
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: عندما يهبط الهواء بقوة على جوانب الجبال نحو السهول أو الوديان المجاورة؛
# Question: كيف يتم تخزين الهواء ذاتيا؟
# Actual Answer: عندما يهبط الهواء بقوة على جوانب الجبال نحو السهول أو الوديان المجاورة؛
# Answer without Paragraph: ##زين
# Answer with Paragraph:
# -------
# Answers field: بسبب ارتباطهما الوثيق مع اسم سونيك
# Question: لماذا ينسب عمل ناتواوشيما في كثير من الاحيان ليوجي وهيروكازو  على سلسة سونيك؟
# Actual Answer: بسبب ارتباطهما الوثيق مع اسم سونيك
# Answer without Paragraph: ينسب عمل ناتواوشيما في كثير من الاحيان ليوجي وهيروكازو على سلسة سونيك ؟ Answer : [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Answer with Paragraph:
# -------
# Answers field: هو لاعب كرة قدم إيراني يلعب مع نادي تراكتور سازي في دوري المحترفين الإيراني كلاعب وسط. مثّل منتخب إيران لكرة القدم. بدأ سعيد آقائي مسيرته الرياضية عام 2012 مع نادي غسترش فولاد. دعي آقائي إلى تشكيلة منتخب إيران الأول من قبل كارلوس كيروش لوديتين ضد مقدونيا وقيرغيزستان في يونيو 2016._x000D_
# _x000D_
#
# Question: كيف كانت حياة سعيد آقائي الرياضية؟
# Actual Answer: هو لاعب كرة قدم إيراني يلعب مع نادي تراكتور سازي في دوري المحترفين الإيراني كلاعب وسط. مثّل منتخب إيران لكرة القدم. بدأ سعيد آقائي مسيرته الرياضية عام 2012 مع نادي غسترش فولاد. دعي آقائي إلى تشكيلة منتخب إيران الأول من قبل كارلوس كيروش لوديتين ضد مقدونيا وقيرغيزستان في يونيو 2016._x000D_
# _x000D_
#
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: أنها مخولة بالحصول على نسخة من كل كتاب ينشر في جمهورية أيرلندا.
# Question: ما سبب كون المكتبة البحثية الرئسية  من ثاني اكبر مكتبة  في بريطانيا  ؟
# Actual Answer: أنها مخولة بالحصول على نسخة من كل كتاب ينشر في جمهورية أيرلندا.
# Answer without Paragraph: ##كتبة البحثية الرئسية من ثاني ا
# Answer with Paragraph: على نسخة من كل كتاب ينشر في جمهورية أيرلندا. وتعد مكتبة بودلي بشكل أساسي مختصة بالمراجع ولا يسمح بالاستعارة إلى في مجال ضيق أو عن طريق المكتبات الأخرى التابعة لها. وهو بناء مُدرج بالدرجة الأولى. _ x000D _ _ x000D _ Question : ما سبب كون المكتبة البحثية الرئسية
# -------
# Answers field: اكتشفت خيانته لها مع إحدى الفتيات
# Question: لماذا طلبت زوجة يزن السيد الطلاق منه؟
# Actual Answer: اكتشفت خيانته لها مع إحدى الفتيات
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: يقوم الاتحاد الدولي لتاريخ وإحصاءات كرة القدم باختيار المرشحين
# Question: كيف تمنح جائزة افضل حارس من الاتحاد الدولي؟
# Actual Answer: يقوم الاتحاد الدولي لتاريخ وإحصاءات كرة القدم باختيار المرشحين
# Answer without Paragraph: ##wer : [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Answer with Paragraph: سنوياً منذ 1987 من قبل الاتحاد الدولي لتاريخ وإحصاءات كرة القدم ، وتمنح إلى الحار
# -------
# Answers field: بسبب إحتوئه لمشاهد مخلة بالحياء
# Question: علل سبب عدم عرض فيلم الممثل هشام موسون لحظة ظلام في بلده؟
# Actual Answer: بسبب إحتوئه لمشاهد مخلة بالحياء
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: يعني "المكان الحقيقي
# Question: لماذا يطلقون اليابانيون على مشهد الجريمة جينبا؟
# Actual Answer: يعني "المكان الحقيقي
# Answer without Paragraph: ##ون اليابانيون على مشهد الجريمة جينبا ؟ Answer : [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Answer with Paragraph:
# -------
# Answers field: لدعم وتنمية التقدم الاقتصادي والاجتماعي للدول الأعضاء
# Question: علل سبب إنشاء البنك الإسلامي للتنمية؟
# Actual Answer: لدعم وتنمية التقدم الاقتصادي والاجتماعي للدول الأعضاء
# Answer without Paragraph: [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Answer with Paragraph:
# -------
# Answers field: درس القانون في تيري هوت أصبح
# Question: كيف كانت دراسة نيوتن بوث؟
# Actual Answer: درس القانون في تيري هوت أصبح
# Answer without Paragraph: [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Answer with Paragraph:
# -------
# Answers field: أهم الأحزاب التونسية.
# Question: لماذا هو الحزب الديمقراطي
# Actual Answer: أهم الأحزاب التونسية.
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: يحسّن صفات المادة الكيميائيّة
# Question: لماذا يمزج المبيدات الحشرية؟
# Actual Answer: يحسّن صفات المادة الكيميائيّة
# Answer without Paragraph: المبيدات
# Answer with Paragraph:
# -------
# Answers field: طلبا للعلم
# Question: لماذا ارتحل إبراهيم العجلوني إلى حلب؟
# Actual Answer: طلبا للعلم
# Answer without Paragraph: ##wer : [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Answer with Paragraph:
# -------
# Answers field: من خلال مطبوعتي المقتطف والهلال اللتان تأسستا على التوالي عامي 1876 و1892م
# Question: كيف كانت طريقة نقولا حداد في ترويج أفكارة؟
# Actual Answer: من خلال مطبوعتي المقتطف والهلال اللتان تأسستا على التوالي عامي 1876 و1892م
# Answer without Paragraph:
# Answer with Paragraph: الأميركية في بيروت فيما بعد ) ثم هاجر من بعد إلى مصر واستقر بها. عمل في الصحافة فحرر في جريدة الأهرام وغيرها. سافر إلى نيويورك عام 1907 وأشترك مع فرح أنطوان في إصدار الجامعة عاد إلى القاهرة واشترك مع زوجته روز أنطوان حداد مجلة السيدات والرجال التي ظلت تصدر اثنى عشر عاماً. رأس تحرير المقتطف ( 1949 - 1950 ) له طائفة كبيرة من المؤلفات أبرزها " علم الاجتماع " و " هندسة الكون بحسب ناموس النسبية ". له مجموعة كبيرة من الروايات والمسرحيات بين المؤلفة ومترجمة. عمل على ترويج أفكاره من خلال مطبوعتي المقتطف والهلال اللتان تأسستا على التوالي عامي 1876 و1892م. _ x
# -------
# Answers field: حصلت الرقة تذبح بصمت خلالها على عدد من الجوائز العالمية منها جائزة حرية الصحافة العالمية._x000D_
#
# Question: كيف نالت حملة الرقة تذبح بصمت اهتماما حيالها؟
# Actual Answer: حصلت الرقة تذبح بصمت خلالها على عدد من الجوائز العالمية منها جائزة حرية الصحافة العالمية._x000D_
#
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: بسبب الحرب السوفيتيه في أفغانستان._x000D_
#
# Question: لماذا كانت الدورة في لوس انجلوس ؟
# Actual Answer: بسبب الحرب السوفيتيه في أفغانستان._x000D_
#
# Answer without Paragraph: انجلوس
# Answer with Paragraph:
# -------
# Answers field: لتجنب فقدان كميات المياه
# Question: لماذا يتم وضع البوابة في فتحة قنوات هندسة الري؟
# Actual Answer: لتجنب فقدان كميات المياه
# Answer without Paragraph:
# Answer with Paragraph: يدعمه مفصلات أو محور أفقي أو عمودي دوار ، الذي قد يثبت في أطراف الأنبوب أو القناة الكبيرة من أجل السيطرة على تدفق المياه أو أي سوائل من أحد الجوانب إلى الآخر. عادة ما تُوضع في فتحة قنوات هندسة الري لتجنب فقدان كميات المياه أو نهاية قنوات الصرف لتجنب مدخل المياه. _ x000D _ _ x000D _ Question : لماذا يتم وضع البوابة في فتحة قنوات هندسة ال
# -------
# Answers field: تمنح الكتب في السلسلة مقدمات موجزة حول مواضيع معينة، تستهدف جمهورا عاما، و لكن مكتوبة من قبل خبراء في المجال
# Question: كيف تكون طريقة تأليف سلسلة كتب مقدمات قصيرة جدًا؟
# Actual Answer: تمنح الكتب في السلسلة مقدمات موجزة حول مواضيع معينة، تستهدف جمهورا عاما، و لكن مكتوبة من قبل خبراء في المجال
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: أول من صاغ نظرية مركزية الشمس وكون الأرض جرماً يدور في فلكها في كتابه "حول دوران الأجرام السماوية". وهو مطور نظرية دوران الأرض، ويعتبر مؤسس علم الفلك الحديث
# Question: لماذا يعتبر كوبرنيكوس من أعظم علماء عصره؟
# Actual Answer: أول من صاغ نظرية مركزية الشمس وكون الأرض جرماً يدور في فلكها في كتابه "حول دوران الأجرام السماوية". وهو مطور نظرية دوران الأرض، ويعتبر مؤسس علم الفلك الحديث
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: بخفة وزنها وقوة تحملها ولا يمكن التقاطها من خلال أجهزة الرادار والاستطلاع
# Question: كيف تتميز طائرات أمل 300-3؟
# Actual Answer: بخفة وزنها وقوة تحملها ولا يمكن التقاطها من خلال أجهزة الرادار والاستطلاع
# Answer without Paragraph:
# Answer with Paragraph: التقاطها من خلال أجهزة الرادار والاستطلاع ، ويتم برمجتها من خلال غرفة تحكم أرضية. _ x
# -------
# Answers field:  المأساة و التاريخ و الكوميديا .
# Question: كيف تقسمت مسرحيات شكسبير
# Actual Answer:  المأساة و التاريخ و الكوميديا .
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: إعلامية وباحثة اجتماعية وصحفية وروائية
# Question: كيف كانت حياة فوزية سلامة العملية؟
# Actual Answer: إعلامية وباحثة اجتماعية وصحفية وروائية
# Answer without Paragraph:
# Answer with Paragraph: فوزية سلامة ( 15 يونيو 1941 - 28 يوليو 2014 ) ، إعلامية
# -------
# Answers field:  بتوفر شرطين:_x000D_
# _x000D_
# و قيمة الزاوية الحرجة ليست ثابتة في كل الأحوال بل تتبدل بتبدل الأوساط التي ينتقل فيها الشعاع الضوئي ( أو أي شعاع كهرومغناطيسي على وجه العموم). علما أنه في كل الأحوال, فإن زاوية الانعكاس تساوي تماما زاوية السقوط._x000D_
# _x000D_
#
# Question: كيف يتم الانعكاس؟
# Actual Answer:  بتوفر شرطين:_x000D_
# _x000D_
# و قيمة الزاوية الحرجة ليست ثابتة في كل الأحوال بل تتبدل بتبدل الأوساط التي ينتقل فيها الشعاع الضوئي ( أو أي شعاع كهرومغناطيسي على وجه العموم). علما أنه في كل الأحوال, فإن زاوية الانعكاس تساوي تماما زاوية السقوط._x000D_
# _x000D_
#
# Answer without Paragraph:
# Answer with Paragraph: الأحوال بل تتبدل بتبدل الأوساط
# -------
# Answers field: تربي أبنائها الصغار معها في عائلتها
# Question: كيف يربي طائر كاسر الجوز صغاره؟
# Actual Answer: تربي أبنائها الصغار معها في عائلتها
# Answer without Paragraph:
# Answer with Paragraph: معظم الأنواع شريط عازل لونه أسود حول العينين ، وريش علوي لونه بين الأزرق والرمادي. _ x
# -------
# Answers field: بموجب مرسوم لمجلس وزراء الاتحاد السوفييتي.
# Question: لماذا انشات عام 1946 بالتحديد؟
# Actual Answer: بموجب مرسوم لمجلس وزراء الاتحاد السوفييتي.
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: بقصد التعمية والإلغاز
# Question: ماسبب اختراع العلماء القلم الرومي ؟
# Actual Answer: بقصد التعمية والإلغاز
# Answer without Paragraph: : ماسبب اختراع العلماء القلم الرومي ؟ Answer : [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Answer with Paragraph: مطَّردة لآحاد الآلاف وما فوقها ، إلى ما لا نهاية له ، وهذه الطريقة في الأساس اخترعها العلماء في بلاد المغرب الأقصى بقصد التعمية والإلغاز ، فلم يكن يفهمها غيرهم. _ x
# -------
# Answers field: هو عبارة عن إفرازات مخاطية خاصةً مجري البول أو المهبل
# Question: كيف كان يتكون داء السيلان
# Actual Answer: هو عبارة عن إفرازات مخاطية خاصةً مجري البول أو المهبل
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: (Eurasian Plate). تقع هذه الحافة في المحيط القطبي الشمالي (Arctic Ocean) بين غرينلاند (Greenland) وسيبيريا (Siberia)، ويبلغ طولها 1,800 كيلو متر تقريبًا. تربط الحافة جيولوجيًا الطرف الشمالي لحافة منتصف المحيط الأطلسي (Mid-Atlantic Ridge) بصدع بحر لابتيف (Laptev Sea Rift)._x000D_
#
# Question: كيف يراد بمفهوم الصفيحة الأوراسية؟
# Actual Answer: (Eurasian Plate). تقع هذه الحافة في المحيط القطبي الشمالي (Arctic Ocean) بين غرينلاند (Greenland) وسيبيريا (Siberia)، ويبلغ طولها 1,800 كيلو متر تقريبًا. تربط الحافة جيولوجيًا الطرف الشمالي لحافة منتصف المحيط الأطلسي (Mid-Atlantic Ridge) بصدع بحر لابتيف (Laptev Sea Rift)._x000D_
#
# Answer without Paragraph: ##فهوم
# Answer with Paragraph: mid - oceanic ridge ) ، وتباين في حد الصفائح تكتوني بين صفيحة أمريكا الشمالية ( North American Plat ) والصفيحة الأوراسية ( Eurasian Plate ). تقع هذه الحافة في المحيط القطبي الشمالي ( Arctic Ocean ) بين غرينلاند ( Greenland ) وسيبيريا ( Siberia ) ، ويبلغ طولها 1, 800 كيلو متر تقريبًا. تربط الحافة جيولوجيًا الطرف الشمالي
# -------
# Answers field: سبب الإيمان والتراث المسيحي الأرثوذكسي المشترك بين الإغريق البيزنطيين والجورجيين._x000D_
#
# Question: لماذا تم المستوطنين الإغريق في منطقة القوقاز؟
# Actual Answer: سبب الإيمان والتراث المسيحي الأرثوذكسي المشترك بين الإغريق البيزنطيين والجورجيين._x000D_
#
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: لا يوجد لفريتاون حاكم محلي
# Question: لماذا لا تعتبر قرية فريتاون كقرية؟
# Actual Answer: لا يوجد لفريتاون حاكم محلي
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: أنشئ مجلس البحث العلمي في عام 2005م بموجب المرسوم السلطاني رقم 54/2005 وتتمثل المهمة الرئيسة للمجلس في إعداد استراتيجية وطنية للبحث العلمي والسعي إلى تعزيز ودعم البحوث باستخدام جميع الوسائل المتاحة المادية منها والمعنوية.
# Question: كيف تم انشاء مجلس البحث العلمي في سلطنة عمان؟
# Actual Answer: أنشئ مجلس البحث العلمي في عام 2005م بموجب المرسوم السلطاني رقم 54/2005 وتتمثل المهمة الرئيسة للمجلس في إعداد استراتيجية وطنية للبحث العلمي والسعي إلى تعزيز ودعم البحوث باستخدام جميع الوسائل المتاحة المادية منها والمعنوية.
# Answer without Paragraph:
# Answer with Paragraph: الوسائل المتاحة المادية منها والمعنوية. وبناءا على ما و
# -------
# Answers field: تسويق محاصيل الصفصاف للطاقة الحيوية كمصدر متجدد للوقود الحيوي
# Question: ما سبب إنشاء مشروع إنتاج الكتلة الحيوية باستخدام الصفصاف؟
# Actual Answer: تسويق محاصيل الصفصاف للطاقة الحيوية كمصدر متجدد للوقود الحيوي
# Answer without Paragraph: ##wer : [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Answer with Paragraph: ##أخري في شمال ولاية نيويورك. و يسعي المشروع ، الذي يموله برنامج الطاقة الحيوية للتنمية الريفية في وزارة الطاقة الأميركية ، إلي تسويق
# -------
# Answers field: قع على تلة صخرية صغيرة فوق وادي سارين
# Question: كيف يمكن وصف موقع فريبورغ؟
# Actual Answer: قع على تلة صخرية صغيرة فوق وادي سارين
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: على تلفزيون طوكيو
# Question: كيف تم عرض اول حلقة لمسلسل  بسمه و عبدو
# Actual Answer: على تلفزيون طوكيو
# Answer without Paragraph:
# Answer with Paragraph: な 小 人 たち ベルフィーとリルビット | Mori no Yōki na Kobitotachi : أقزام الغابة المبهجون : بيلفي وليلابيت ) مسلسل أنمي أنتج باللغة اليابانية ويتكون من 26 حلقة. أنتجته تاتسونوكو للإنتاج عام 1980 في اليابان. أول عرض له كان على تلفزيون طوكيو ( الذي تغيّر اسمه لاحقاً ليصبح قناة طوكيو 12 ) ، بينما عرضت النسخ المدبلجة إلى الإنجليزية على محطة تلفزيون الأطفال نيكولوديون في الفترة من 1991 حتى 1995 إلى جانب مسلسلات أنيمي أخرى كمغامرات كوالا الصغير ومغامرات زينة ونحول والأحلام
# -------
# Answers field: تعود تسمية اگزناية إلى القبيلة الريفية اگزناية أو ايزناين
# Question: كيف تمت تسمية اكزناية؟
# Actual Answer: تعود تسمية اگزناية إلى القبيلة الريفية اگزناية أو ايزناين
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: تم تشكيلها من اتحاد تنجانيقا مع الارخبيل الساحلي لزنجبار.
# Question: كيف تم تكوين تنزانيا؟
# Actual Answer: تم تشكيلها من اتحاد تنجانيقا مع الارخبيل الساحلي لزنجبار.
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: نتهت المحافظة وحلت بموجب قرار فك الارتباط الإداري والقانوني عام 1988 م._x000D_
#
# Question: كيف انتهت محافظة الخليل؟
# Actual Answer: نتهت المحافظة وحلت بموجب قرار فك الارتباط الإداري والقانوني عام 1988 م._x000D_
#
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: لم يتم تبني هذه المبادئ من قبل الدول كمعاهدة
# Question: لماذا لا تشكل مبادئ يوغياكارتاقانونيا جزءا لمعاهدات حقوق الانسان؟
# Actual Answer: لم يتم تبني هذه المبادئ من قبل الدول كمعاهدة
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field:  تعريضه الأشعّة فوق البنفسجيّة ذات الطول الموجي القصير._x000D_
#
# Question: كيف يمكن ان يظهر اللون الاخضر في الفيلميت ؟
# Actual Answer:  تعريضه الأشعّة فوق البنفسجيّة ذات الطول الموجي القصير._x000D_
#
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: حصل 526 أوروبي على جائزة نوبل
# Question: لماذا يعتبر الاوروبيون هم الذين ساهموا في تطوير الحضارة الانسانية؟
# Actual Answer: حصل 526 أوروبي على جائزة نوبل
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: عندما يهبط الهواء بقوة على جوانب الجبال نحو السهول أو الوديان المجاورة
# Question: ما سبب انخفاض درجه حراره الهواء على جوانب الجبال؟
# Actual Answer: عندما يهبط الهواء بقوة على جوانب الجبال نحو السهول أو الوديان المجاورة
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: وبلغ طول الامتداد الأصلي للجسر وقت افتتاحه في عام 1952 4.3 ميل (6.9 كم)
# Question: لماذا يعد الجسر التذكاري لوليام بريستون لين الابن من أطول الإنشاءات الفولاذية المستمرة فوق الماء؟
# Actual Answer: وبلغ طول الامتداد الأصلي للجسر وقت افتتاحه في عام 1952 4.3 ميل (6.9 كم)
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: قد تؤثر تلك المخاطر على كلا جوانب الميزانية العمومية
# Question: لماذا الاكتواري يتطلب مهارات عالية؟
# Actual Answer: قد تؤثر تلك المخاطر على كلا جوانب الميزانية العمومية
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: يهدف إلى فهم المشكلة وتفسير البيانات واستخدام تلك العناصر لمنع وقوع المشكلة مرة أخرى
# Question: كيف يختلف المنهج التحليلي  الصناعي عن المنهج التحليلي  التقليدي؟
# Actual Answer: يهدف إلى فهم المشكلة وتفسير البيانات واستخدام تلك العناصر لمنع وقوع المشكلة مرة أخرى
# Answer without Paragraph:
# Answer with Paragraph: يفحص كل خطوة في دورة حياة المُنتج بدءًا من البحث والتطوير ( R & D ) وحتى الوصول إلى المنتج النهائي وما يلي ذلك من التنبؤ بمشاكل التصنيع وتحديدها ومنعها وحلها. _ x
# -------
# Answers field: دخلت وحدات من الولايات المتحدة وأستراليا للمساعدة وقد أنقذ جميع الركاب والطاقم البالغ عددهم 53 شخصا._x000D_
#
# Question: كيف تم انقاذ خطوط كانتس الجوية الرحلة 1737 من الاختطاف؟
# Actual Answer: دخلت وحدات من الولايات المتحدة وأستراليا للمساعدة وقد أنقذ جميع الركاب والطاقم البالغ عددهم 53 شخصا._x000D_
#
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: ويقدر سكانها 47302 نسمة
# Question: كم يقدر سكانها مدينة صباح الاحمد السكينة؟
# Actual Answer: ويقدر سكانها 47302 نسمة
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: ناي بريث أنها ملتزمة بأمن واستمرارية الشعب اليهودي ودولة إسرائيل ومكافحة معاداة السامية والتعصب الأعمى. وتتمثل مهمتها بتوحيد أتباع الدين اليهودي، وتعزيز الهوية اليهودية من خلال تعزيز الحياة الأسرية اليهودية، لتقديم الخدمات على نطاق واسع لصالح كبار السن من المواطنين، وتيسيراً للدعوة والعمل بالنيابة عن اليهود في جميع أنحاء العالم._x000D_
#
# Question: كيف تعمل منظمة بناي بريث؟
# Actual Answer: ناي بريث أنها ملتزمة بأمن واستمرارية الشعب اليهودي ودولة إسرائيل ومكافحة معاداة السامية والتعصب الأعمى. وتتمثل مهمتها بتوحيد أتباع الدين اليهودي، وتعزيز الهوية اليهودية من خلال تعزيز الحياة الأسرية اليهودية، لتقديم الخدمات على نطاق واسع لصالح كبار السن من المواطنين، وتيسيراً للدعوة والعمل بالنيابة عن اليهود في جميع أنحاء العالم._x000D_
#
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: النخبة في القوات المسلحة اليمنية
# Question: لماذا تتميز قوات العمالقة في اليمن عن بقية الجيش؟
# Actual Answer: النخبة في القوات المسلحة اليمنية
# Answer without Paragraph: ##wer : [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Answer with Paragraph: متواجد
# -------
# Answers field: أن العنف المنزلي يشكل مشكلةً
# Question: لماذا انشاءت البرازيل شرطة نسائية؟
# Actual Answer: أن العنف المنزلي يشكل مشكلةً
# Answer without Paragraph:
# Answer with Paragraph: ##نف الجسدي أو النفسي. رغم اعتراف البرازيل في الأربعينات بأن العنف المنزلي يشكل مشكلةً ، إلا أن الحكومة لم تتخذ إجراءات لمواجهته إلا منذ الثمانينات ، وذلك بإنشاء مركز الشرطة النسائية ( Delegacia da Mulher ) ، ومؤخرا في 2006 بإصدار قانون العنف المنزلي. _ x000D _ _ x000D _ Question : لماذا انشاءت البرازيل شرطة نسائية
# -------
# Answers field: للمساعدة في عملية السلام في أيرلندا الشمالية
# Question: لماذا بعث جورج ميتشيل الى الولايات المتحدة ؟
# Actual Answer: للمساعدة في عملية السلام في أيرلندا الشمالية
# Answer without Paragraph: ##يتشيل الى الولايات المتحدة
# Answer with Paragraph: المتميزة من وزارة الخارجية. _ x000D _ _ x000D _ Question : لماذا بعث جورج ميتشيل الى الولايات المتحدة
# -------
# Answers field: الغايةُ منه الإسهامُ في خلق نهضة ثقافية كبيرة تكون مواصلة لما قدّمه العرب في القرون السابقة._x000D_
#
# Question: لماذا أنشئت دار الاداب؟
# Actual Answer: الغايةُ منه الإسهامُ في خلق نهضة ثقافية كبيرة تكون مواصلة لما قدّمه العرب في القرون السابقة._x000D_
#
# Answer without Paragraph:
# Answer with Paragraph: بتوجّه تنويري ، الغايةُ منه الإسهامُ في خلق نهضة ثقافية كبيرة تكون مواصلة لما قدّمه العرب في القرون السابقة. _ x000D _ _ x
# -------
# Answers field: كانت تدافع عن التعريف والدفاع عن الصفات الخاصة بالمرأة بوصفها وسيلة لتحقيق استقلالها الذاتي
# Question: كيف كانت تهدف له الحركة النسوية؟
# Actual Answer: كانت تدافع عن التعريف والدفاع عن الصفات الخاصة بالمرأة بوصفها وسيلة لتحقيق استقلالها الذاتي
# Answer without Paragraph:
# Answer with Paragraph: ##وا عدوانيين ومحاربين شرسين ، فإنه على المرأة أن تدرك هذه الاختلافات وأ
# -------
# Answers field: خاصة الكلوروكين والهيدروكسي كلوروكوين تستخدم في علاج التهاب المفاصل الروماتويدي ومرض الذئبة الحمامية المرتبطة بالتهاب المفاصل.
# Question: يف تستخدم علاجات الملاريا؟
# Actual Answer: خاصة الكلوروكين والهيدروكسي كلوروكوين تستخدم في علاج التهاب المفاصل الروماتويدي ومرض الذئبة الحمامية المرتبطة بالتهاب المفاصل.
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: تم التصديق عليها من قبل 83 دولة تمثل نسبة كبيرة من التجارة العالمية
# Question:  لماذا تعتبر اتفاقية الأمم المتحدة بشأن عقود البيع الدولي للبضائع من احدى القوانين الموحدة الدولية الاكثر نجاحا؟
# Actual Answer: تم التصديق عليها من قبل 83 دولة تمثل نسبة كبيرة من التجارة العالمية
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field:  فنان مغربي شامل فهو كاتب أغاني وموزع وملحن ومخرج فيديو كليبات ومنتج أغاني ورجل أعمال ومغني مغربي يتقن العزف على ألة القيثارة وٱكتسب خبرة في عدة ألات أخرى كالطبلة والأورغ
# Question: لماذا بزر أحمد سلطان في الراب المغربي منذ بدياته الأولى؟
# Actual Answer:  فنان مغربي شامل فهو كاتب أغاني وموزع وملحن ومخرج فيديو كليبات ومنتج أغاني ورجل أعمال ومغني مغربي يتقن العزف على ألة القيثارة وٱكتسب خبرة في عدة ألات أخرى كالطبلة والأورغ
# Answer without Paragraph: ##ي منذ بدياته الأولى ؟ Answer :
# Answer with Paragraph:
# -------
# Answers field: انتخب عضو الجمعية التشريعية الأولى لأيرلندا الشمالية عن دائرة وقد انضم خلال (25 يونيو 1998 – 28 أبريل 2003) للكتلة البرلمانية حزب ألستر الوحدوي وفي ، انتخب عضو الجمعية التشريعية الثانية لأيرلندا الشمالية عن دائرة وقد انضم خلال (26 نوفمبر 2003 – 30 يناير 2007) للكتلة البرلمانية حزب ألستر الوحدوي._x000D_
#
# Question: كيف كانت اسهامات جيم ويلسون في الجمعيه التشريعية لايرلندا الشمالية؟
# Actual Answer: انتخب عضو الجمعية التشريعية الأولى لأيرلندا الشمالية عن دائرة وقد انضم خلال (25 يونيو 1998 – 28 أبريل 2003) للكتلة البرلمانية حزب ألستر الوحدوي وفي ، انتخب عضو الجمعية التشريعية الثانية لأيرلندا الشمالية عن دائرة وقد انضم خلال (26 نوفمبر 2003 – 30 يناير 2007) للكتلة البرلمانية حزب ألستر الوحدوي._x000D_
#
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field:  جزءًا من التوسع السوفيتي الغربي
# Question: كيف كان تأثير الحرب الليتوانية السوفيتية ؟
# Actual Answer:  جزءًا من التوسع السوفيتي الغربي
# Answer without Paragraph:
# Answer with Paragraph: بدون مقاومة وسيطروا
# -------
# Answers field:  لحجب مظاهر القاهرة الحديثة
# Question: لماذا تم زراعة ما يقرب عن 5000 شجرة حول القرية؟
# Actual Answer:  لحجب مظاهر القاهرة الحديثة
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: بسبب الحرب العالمية الثانية
# Question: لماذا تعطلت عملية بناء المستشفى الاميري؟
# Actual Answer: بسبب الحرب العالمية الثانية
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: الاندماج البارد
# Question: مالاسم الذي يطلق على تفاعلات اندماج نووي ؟
# Actual Answer: الاندماج البارد
# Answer without Paragraph: يطلق
# Answer with Paragraph: بكثير من درجات الحرارة المطلوبة في التفاعلات النووية الاندماجية المعتادة ( حيث تتطلب تلك التفاعلات ملايين من الدرجات الحرارية على مقياس المئوي وضغط كبير كما هو الحال في بطن الشمس والنجوم ). _ x000D _ _ x000D _ Question : مالاسم الذي يطلق على تفاعلات اندماج
# -------
# Answers field: ولد بتاريخ 20 مايو 1935، أصبح رئيس للأوروغواي بين عامي 2010 و 2015، كان مقاتلاً سابقاً في منظمة توباماروس الثورية اليسارية.
# Question: كيف تهر هوية خوسية ألبرتو "بيبي"؟
# Actual Answer: ولد بتاريخ 20 مايو 1935، أصبح رئيس للأوروغواي بين عامي 2010 و 2015، كان مقاتلاً سابقاً في منظمة توباماروس الثورية اليسارية.
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: تعرّض المسيحيون إلى اضطهادات جمّة وسوء في المعاملة
# Question: لماذا اختفت المسيحية خلال خلافة المتوكل على الله؟
# Actual Answer: تعرّض المسيحيون إلى اضطهادات جمّة وسوء في المعاملة
# Answer without Paragraph:
# Answer with Paragraph: وغيرها من المناطق العصيّة ؛ يسجل التاريخ اللاحق تكررًا للاضطهادات ، أيام المماليك والعثمانيين ، ويُفترض أن الخط الهمايونى الذي صدر عام 1856 هو أول وثيقة ساوت بين المسلمين وغيرهم من م
# -------
# Answers field: الميل إلى الاعتقاد بأن ما يقوم به الفرد يعكس حقيقته الداخلية
# Question: كيف وُصف تأثير الإسناد؟
# Actual Answer: الميل إلى الاعتقاد بأن ما يقوم به الفرد يعكس حقيقته الداخلية
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field:  أخذت اسمها من مدينة لمريك بأيرلندا
# Question: علل سبب تسمية القصيدة اللمريكية بهذا الاسم ؟
# Actual Answer:  أخذت اسمها من مدينة لمريك بأيرلندا
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: بسبب أمراض القلب
# Question: كيف توفي جون برايس؟
# Actual Answer: بسبب أمراض القلب
# Answer without Paragraph: توفي جون برايس ؟ Answer : [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Answer with Paragraph:
# -------
# Answers field: تم تعديل لغة الخطة التدريبية من اللغة العربية إلى اللغة الإنجليزية
# Question: كيف واكبت الكلية التقنيه السعودية التطور التقني؟
# Actual Answer: تم تعديل لغة الخطة التدريبية من اللغة العربية إلى اللغة الإنجليزية
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: بواسطة المرشات المحوريه في منطقة الصحراء._x000D_
#
# Question: كيف تروى المحاصيل الزراعية في جرف النصر؟
# Actual Answer: بواسطة المرشات المحوريه في منطقة الصحراء._x000D_
#
# Answer without Paragraph:
# Answer with Paragraph: تكثر فيها زراعة النخيل وأشجار الفاكهة وكذلك زراعة المحاصيل الحقليه مثل الحنطة والشعير وتسقى بواسطة
# -------
# Answers field: ثلاث أقسام
# Question: كيف قسمت الهجر؟
# Actual Answer: ثلاث أقسام
# Answer without Paragraph: ##wer :
# Answer with Paragraph:
# -------
# Answers field: لتخطيط وتنظيم وتوثيق التعليم
# Question: لماذا تستخدم المحافظ الوظيفية؟
# Actual Answer: لتخطيط وتنظيم وتوثيق التعليم
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: لتفسير سبب وجود استعداد أكبر
# Question: لماذا وضع مفهوم التأهب؟
# Actual Answer: لتفسير سبب وجود استعداد أكبر
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field:  الاستيلاء على المهدية
# Question: كيف كانت نتيجة الحملة المهدية ؟
# ...
# Answer with Paragraph:
# -------
# Answers field:  قصد تمثيل أمتهم ووطنهم وكذلك الشتات الآشوري
# Question: كيف كان المقصود من العلم الآرامي في الاتحاد السرياني في السويد؟
# Actual Answer:  قصد تمثيل أمتهم ووطنهم وكذلك الشتات الآشوري
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: كتيب مطبوع إلكترونياً
# Question: كيف يُعرض "دليل المستخدم" ؟
# Actual Answer: كتيب مطبوع إلكترونياً
# Answer without Paragraph:
# Answer with Paragraph: " User Guide " ) هي وثيقة مساعدة تهدف إلى تقديم المساعدة إلى الأشخاص الذين يستخدمون منتج معين ، وغالباً ما يكون على شكل كتيب مطبوع إلكترونياً أو م
# -------
# Answers field:  تم إنشاؤه عندما قام والد تيلت لصناعة الأحذية بوضع شعار يضم
# Question: لماذا تم انشاء دايموند تي ؟
# Actual Answer:  تم إنشاؤه عندما قام والد تيلت لصناعة الأحذية بوضع شعار يضم
# Answer without Paragraph:
# Answer with Paragraph: من أول حرف من اسم عائلة تيلت " Tilt " ) مؤطر بالماس ، للدلالة على الجودة العالية. ومنذ بداياتها في تصنيع السيارات السياحية ، أصبحت الشركة معروفة لاحقا بشاحناتها. وبحلول عام 1967 ، أصبحت شركة تابعة " لشركة وايت موتور " ( White Motor Company ) ، تم دمجها مع " شركة ريو للسيارات " ( Reo Motor Company ) لتصبح رايموند ريو تروكس ( Diamond Reo Trucks, Inc. ). _ x000D _ _ x000D _ Question : لماذا تم
# -------
# Answers field: يقع حيثما تتفرع القصبة الهوائية بالنسبة للرئتين
# Question: لماذا يختلف المصفار عن حنجرة الثدييات؟
# Actual Answer: يقع حيثما تتفرع القصبة الهوائية بالنسبة للرئتين
# Answer without Paragraph:
# Answer with Paragraph: بالطيور. يقع عند قاعدة القصبة الهوائية ، ويعمل على إصدار الأصوات من دون استخدام الحبال الصوتية ، حيث ينتج الصوت من خلال اهتزاز الجدار الخاص بالمصفار أو بعض أجزائه. هذه الاهتزازات تعمل على تنظيم تدفق الهواء وهو ما يقوم بإصدار الصوت. العضلات تعمل على تعديل شكل الصوت عن طريق تغيير توتر الأغشية وفتحات الشعب الهوائية. المصفار يُمكّن بعض أنواع الطيور كالببغاوات من تقليد كلام البشر. يختلف المصفار عن الحنجرة الخاصة بالثدييات إذ يقع حيثما تتفرع القصبة الهوائية بالنسبة للرئتين. ولذلك فإن هنا
# -------
# Answers field: تعطي أنماطًا متكررة
# Question: لماذا تستخدم الصباغة بالمنع؟
# Actual Answer: تعطي أنماطًا متكررة
# Answer without Paragraph: الصباغة بالم
# Answer with Paragraph: ##طي أنماطًا متكررة. تتلخص الطريقة في منع مادة الصباغة من الوصول إلى كامل القماش فتنتج أشكالا وطرازات نتيجة التباي
# -------
# Answers field: هي رئيسة سيدات مخدع الملكة اليزابيث الأولى، ابنة خالتها الأولى.
# Question: كيف كانت علاقة كاثرين كاري بالملكة اليزابيث الاولى؟
# Actual Answer: هي رئيسة سيدات مخدع الملكة اليزابيث الأولى، ابنة خالتها الأولى.
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: فتتح الجامع في عام 1957م بحضور الملك فيصل الثاني وجمع من وجهاء بغداد وعلمائها
# Question: كيف تم افتتاح جامع الشاوي؟
# Actual Answer: فتتح الجامع في عام 1957م بحضور الملك فيصل الثاني وجمع من وجهاء بغداد وعلمائها
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: ولد جورج كوبر باردي
# Question: لماذا ينتمي الئ الحزب الجمهوري
# Actual Answer: ولد جورج كوبر باردي
# Answer without Paragraph: الجمهوري Answer : [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Answer with Paragraph:
# -------
# Answers field: سبب العجز في الميزانية، والمديونية العالية
# Question: لماذا قررت حكومة رئيس الوزاء الدكتور عبدالله النسور برفع الدعم عن المحروقات في 2012؟
# Actual Answer: سبب العجز في الميزانية، والمديونية العالية
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: إن افتراض مثل هذا التأثير هو الأكثر شعبية حالياً لتفسير تمدد الكون بمعدل متسارع
# Question: ما سبب تمدد الكون بمعدل متسارع؟
# Actual Answer: إن افتراض مثل هذا التأثير هو الأكثر شعبية حالياً لتفسير تمدد الكون بمعدل متسارع
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: تسرد الرواية كيف يحول احتضار بطيئ و معذب، حياة موظف ناجح اجتماعيا، إلى وعي مؤلم بتفاهة حياته و بزيف علاقاته الأسرية و الاجتماعية._x000D_
#
# Question: كيف تم سرد رواية موت إيفان إيليتش؟
# Actual Answer: تسرد الرواية كيف يحول احتضار بطيئ و معذب، حياة موظف ناجح اجتماعيا، إلى وعي مؤلم بتفاهة حياته و بزيف علاقاته الأسرية و الاجتماعية._x000D_
#
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: غرق آر إم إس تيتانيك الكارثي في عام 1912
# Question: لماذا كلف وزير الدعاية بانتاج فيلم تيتانيك ؟
# Actual Answer: غرق آر إم إس تيتانيك الكارثي في عام 1912
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Answers field: استطاع قيادة قوات الحلفاء
# Question: كيف كانت اعماله
# Actual Answer: استطاع قيادة قوات الحلفاء
# Answer without Paragraph:
# Answer with Paragraph: في معركة النورماندي التي نزل فيها الحلفاء إلى أوروبا لمواجهة القوات النازية والتقدم نحو برلين. _ x
# -------
# Answers field: شارك مع منتخب كرواتيا تحت 17 سنة لكرة القدم ومنتخب كرواتيا تحت 19 سنة لكرة القدم ومنتخب كرواتيا تحت 20 سنة لكرة القدم ومنتخب كرواتيا تحت 21 سنة لكرة القدم
# Question: كيف كانت مشاركات طوني جوروبيك مع منتخب كرولتيا؟
# Actual Answer: شارك مع منتخب كرواتيا تحت 17 سنة لكرة القدم ومنتخب كرواتيا تحت 19 سنة لكرة القدم ومنتخب كرواتيا تحت 20 سنة لكرة القدم ومنتخب كرواتيا تحت 21 سنة لكرة القدم
# Answer without Paragraph:
# Answer with Paragraph:
# -------
# Map:   0%|          | 0/4450 [00:00<?, ? examples/s]
# Answer not found in context for entry 23. Skipping.
# Answer not found in context for entry 91. Skipping.
# Answer not found in context for entry 94. Skipping.
# Answer not found in context for entry 101. Skipping.
# Answer not found in context for entry 258. Skipping.
# Answer not found in context for entry 492. Skipping.
# Answer not found in context for entry 568. Skipping.
# Answer not found in context for entry 760. Skipping.
# Answer not found in context for entry 781. Skipping.
# Answer not found in context for entry 831. Skipping.
# Answer not found in context for entry 932. Skipping.
# Answer not found in context for entry 972. Skipping.
# Answer not found in context for entry 985. Skipping.
# Answer not found in context for entry 991. Skipping.
# Answer not found in context for entry 16. Skipping.
# Answer not found in context for entry 112. Skipping.
# Answer not found in context for entry 119. Skipping.
# Answer not found in context for entry 132. Skipping.
# Answer not found in context for entry 160. Skipping.
# Answer not found in context for entry 186. Skipping.
# Answer not found in context for entry 208. Skipping.
# Answer not found in context for entry 213. Skipping.
# Answer not found in context for entry 220. Skipping.
# Answer not found in context for entry 230. Skipping.
# Answer not found in context for entry 240. Skipping.
# Answer not found in context for entry 261. Skipping.
# Answer not found in context for entry 289. Skipping.
# Answer not found in context for entry 312. Skipping.
# Answer not found in context for entry 365. Skipping.
# Answer not found in context for entry 397. Skipping.
# Answer not found in context for entry 421. Skipping.
# Answer not found in context for entry 433. Skipping.
# Answer not found in context for entry 459. Skipping.
# Answer not found in context for entry 514. Skipping.
# Answer not found in context for entry 537. Skipping.
# Answer not found in context for entry 553. Skipping.
# Answer not found in context for entry 587. Skipping.
# Answer not found in context for entry 676. Skipping.
# Answer not found in context for entry 682. Skipping.
# Answer not found in context for entry 711. Skipping.
# Answer not found in context for entry 758. Skipping.
# Answer not found in context for entry 793. Skipping.
# Answer not found in context for entry 842. Skipping.
# Answer not found in context for entry 32. Skipping.
# Answer not found in context for entry 82. Skipping.
# Answer not found in context for entry 125. Skipping.
# Answer not found in context for entry 251. Skipping.
# Answer not found in context for entry 368. Skipping.
# Answer not found in context for entry 404. Skipping.
# Answer not found in context for entry 424. Skipping.
# Answer not found in context for entry 557. Skipping.
# Answer not found in context for entry 609. Skipping.
# Answer not found in context for entry 631. Skipping.
# Answer not found in context for entry 654. Skipping.
# Answer not found in context for entry 671. Skipping.
# Answer not found in context for entry 722. Skipping.
# Answer not found in context for entry 734. Skipping.
# Answer not found in context for entry 768. Skipping.
# Answer not found in context for entry 952. Skipping.
# Answer not found in context for entry 971. Skipping.
# Answer not found in context for entry 972. Skipping.
# Answer not found in context for entry 977. Skipping.
# Answer not found in context for entry 996. Skipping.
# Answer not found in context for entry 14. Skipping.
# Answer not found in context for entry 92. Skipping.
# Answer not found in context for entry 233. Skipping.
# Answer not found in context for entry 265. Skipping.
# Answer not found in context for entry 323. Skipping.
# Answer not found in context for entry 331. Skipping.
# Answer not found in context for entry 435. Skipping.
# Answer not found in context for entry 446. Skipping.
# Answer not found in context for entry 465. Skipping.
# Answer not found in context for entry 644. Skipping.
# Answer not found in context for entry 744. Skipping.
# Answer not found in context for entry 898. Skipping.
# Answer not found in context for entry 957. Skipping.
# Answer not found in context for entry 967. Skipping.
# Answer not found in context for entry 89. Skipping.
# Answer not found in context for entry 147. Skipping.
# Answer not found in context for entry 196. Skipping.
# Answer not found in context for entry 203. Skipping.
# Answer not found in context for entry 423. Skipping.
# Map:   0%|          | 0/1113 [00:00<?, ? examples/s]
# Answer not found in context for entry 19. Skipping.
# Answer not found in context for entry 106. Skipping.
# Answer not found in context for entry 123. Skipping.
# Answer not found in context for entry 163. Skipping.
# Answer not found in context for entry 164. Skipping.
# Answer not found in context for entry 188. Skipping.
# Answer not found in context for entry 235. Skipping.
# Answer not found in context for entry 243. Skipping.
# Answer not found in context for entry 269. Skipping.
# Answer not found in context for entry 338. Skipping.
# Answer not found in context for entry 358. Skipping.
# Answer not found in context for entry 442. Skipping.
# Answer not found in context for entry 453. Skipping.
# Answer not found in context for entry 501. Skipping.
# Answer not found in context for entry 507. Skipping.
# Answer not found in context for entry 564. Skipping.
# Answer not found in context for entry 594. Skipping.
# Answer not found in context for entry 598. Skipping.
# Answer not found in context for entry 656. Skipping.
# Answer not found in context for entry 664. Skipping.
# Answer not found in context for entry 748. Skipping.
# Answer not found in context for entry 755. Skipping.
# Answer not found in context for entry 21. Skipping.
# Answer not found in context for entry 33. Skipping.
# Answer not found in context for entry 44. Skipping.
# Answer not found in context for entry 54. Skipping.
# Answer not found in context for entry 75. Skipping.
# Answer not found in context for entry 79. Skipping.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: mostafahosen042 (mostafahosen042-freelancer) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>/content/wandb/run-20250805_094028-645i5f32</code>
# Syncing run <strong><a href='https://wandb.ai/mostafahosen042-freelancer/huggingface/runs/645i5f32' target="_blank">./results</a></strong> to <a href='https://wandb.ai/mostafahosen042-freelancer/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/mostafahosen042-freelancer/huggingface' target="_blank">https://wandb.ai/mostafahosen042-freelancer/huggingface</a>
#  View run at <a href='https://wandb.ai/mostafahosen042-freelancer/huggingface/runs/645i5f32' target="_blank">https://wandb.ai/mostafahosen042-freelancer/huggingface/runs/645i5f32</a>
#     <div>
#
#       <progress value='2468' max='222500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  2468/222500 12:06 < 18:00:49, 3.39 it/s, Epoch 1.11/100]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>6.604900</td>
#       <td>nan</td>
#       <td>0.191824</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
